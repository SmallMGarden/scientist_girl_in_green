# %% [markdown]
# <a href="https://colab.research.google.com/github/SmallMGarden/scientist_girl_in_green/blob/main/%D0%9A%D0%BE%D1%87%D0%BA%D1%83%D1%80%D0%BE%D0%B2%D0%B0_%222_hw_tokenization_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание: Модуль токенизации текста

# %% [markdown]
# ## Задание
#
# Создать модуль `tokenizer.py`, который реализует токенизацию текста тремя разными способами и может использоваться как подгружаемая библиотека.

# %% [markdown]
# ### Функциональные требования
#
# 1. Модуль должен принимать текстовую строку на вход
# 2. Реализовать три метода токенизации:
#   - Простая токенизация по пробелам и знакам препинания
#   - Токенизация с использованием NLTK
#   - Токенизация с использованием spaCy
# 3. Модуль должен выводить результаты всех трех методов
# 4. Должен быть предоставлен скрипт для демонстрации работы модуля

# %% [markdown]
# ### Технические требования
#
# 1. Модуль должен быть импортируемым (`import tokenizer`)
# 2. Код должен быть хорошо документирован
# 3. Обработка ошибок (например, отсутствие необходимых библиотек)
# 4. Требования к зависимостям в `requirements.txt`

# %% [markdown]
# ### Результат работы
#
# В качестве результата работы нужно представить tokenizer.zip либо ссылку на репозиторий на GitHub со следующей структурой
#
# ```
# tokenization_hw/
# ├── tokenizer.py
# ├── demo.py
# ├── requirements.txt
# └── README.md
# ```
#
# где:
#
# - `tokenization_hw` - папка, созданная в вашем репозитории
# - `tokenizer.py` - только класс (модуль) для токенизации текста
# - `demo.py` - скрипт с демонстрацией работы вашей программы
# - `requirements.txt` - файл с перечислением пакетов, которые необходимо установить для работы вашей программы
# - `README.md` - файл с описанием процесса вашей работы, например, "создан класс ... для ... с помощью бибиотек" и примерами запуска программы

# %% [markdown]
# ### Примерная структура `tokenizer.py`

# %%
"""
Модуль для токенизации текста различными способами
"""

import re

class TextTokenizer:
    def __init__(self):
        """Инициализация токенизатора: не изменяйте эту строчку кода"""
        pass

    def simple_tokenize(self, text):
        """
        Простая токенизация по пробелам и знакам препинания

        Args:
            text (str): Входной текст

        Returns:
            list: Список токенов
        """
        # Реализация простой токенизации, прочитала, что можно установить и вторую границу с помощью \b
        tokens = re.findall(r"\b\w+\b", text)
        return tokens

    def nltk_tokenize(self, text):
        """
        Токенизация с использованием NLTK

        Args:
            text (str): Входной текст

        Returns:
            list: Список токенов или сообщение об ошибке
        """
        # Реализация NLTK токенизации, true научилась делать еще с работы в классе!
        try:
            import nltk
            nltk.download('punkt_tab',quiet=True)
            from nltk.tokenize import word_tokenize
            return word_tokenize(text)
        except:
            print('Error: can not tokenize (nltk)')
            return None

    def spacy_tokenize(self, text):
        """
        Токенизация с использованием spaCy

        Args:
            text (str): Входной текст

        Returns:
            list: Список токенов или сообщение об ошибке
        """
        # Реализация spaCy токенизации
        try:
            import spacy
            nlp = spacy.load("en_core_web_sm")
            return [t.text for t in nlp(text)]
        except:
            print('Error: can not tokenize (spacy)')
            return None

    def tokenize_all(self, text):
        """
        Применяет все доступные методы токенизации

        Args:
            text (str): Входной текст

        Returns:
            dict: Словарь с результатами всех методов
        """
        # Реализация вызова всех методов
        return {
        "simple": self.simple_tokenize(text),
        "nltk": self.nltk_tokenize(text) or [],
        "spacy": self.spacy_tokenize(text) or []
        }

def demo():
    """Демонстрационная функция"""
    # Пример использования

    tokenizer = TextTokenizer()

    # Пример текста для токенизации
    sample_text = "Hello, world! This is a test sentence. How are you today?"

    # Применяем все методы токенизации
    results = tokenizer.tokenize_all(sample_text)

    # Выводим результаты
    for method, tokens in results.items():
        print(f"{method}: {tokens}")

if __name__ == "__main__":
    demo()
# Out:
# simple: ['Hello', 'world', 'This', 'is', 'a', 'test', 'sentence', 'How', 'are', 'you', 'today']
# nltk: ['Hello', ',', 'world', '!', 'This', 'is', 'a', 'test', 'sentence', '.', 'How', 'are', 'you', 'today', '?']
# spacy: ['Hello', ',', 'world', '!', 'This', 'is', 'a', 'test', 'sentence', '.', 'How', 'are', 'you', 'today', '?']

# %% [markdown]
# ### Пример `demo.py`

# %%
from tokenizer import TextTokenizer

def main():
    tokenizer = TextTokenizer()

    # Пример текста для токенизации
    sample_text = "Hello, world! This is a test sentence. How are you today?"

    # Применяем все методы токенизации
    results = tokenizer.tokenize_all(sample_text)

    # Выводим результаты
    for method, tokens in results.items():
        print(f"{method}: {tokens}")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Пример `requirements.txt`
#
# Это специальный файл со списком библиотек, которые Python установит автоматически перед запуском программы. Его не нужно менять, просто создать и сохранить в папке с вашим домашним заданием. Инструкция по запуску - ниже.
#
# ```
# nltk
# spacy
# ```

# %% [markdown]
# ### Инструкции по выполнению

# %% [markdown]
# #### Шаг 1: Настройка окружения
#
# Строки ниже можно ввести в терминал vs code, чтобы посмотреть на результат вашей работы
#
# ```
# # Создание виртуального окружения (рекомендуется)
# python -m venv tokenizer_env
# source tokenizer_env/bin/activate  # Linux/Mac (также работает в VS Code на Windows)
#
# # Установка зависимостей
# pip install -r requirements.txt
#
# # Дополнительно для spaCy (после установки spaCy)
# python3 -m spacy download en_core_web_sm
# ```

# %% [markdown]
# #### Шаг 2: Реализация функций
#
# 1. Заполните методы в TextTokenizer
# 2. Реализуйте простую токенизацию с использованием регулярных выражений
# 3. Добавьте обработку ошибок для случаев, когда библиотеки не установлены
# 4. Напишите документацию для каждого метода

# %% [markdown]
# #### Шаг 3: Тестирование
#
# Это вводим в терминал VS Code для проверки работоспособности кода:
#
# ```
# # Тестирование модуля
# python3 demo.py
# ```

# %% [markdown]
# #### Шаг 4: Сдача решения
#
# ##### Требования к репозиторию:
#
# - Структура файлов должна соответствовать указанной выше
# - Напишите README.md с инструкциями по установке и использованию
#
# ##### Что должно быть в README.md:
#
# - Описание проекта: что сделали, какие бибиблиотеки использоваил
# - Инструкции по установке: инструкции можно взять из условия домашнего задания (см. "Шаг 1: Настройка окружения")
# - Примеры использования: здесь нужно привести строки кода из `demo.py`
# - Описание методов: перечислите функции, которые вы дописали при выполнении домашнего задания
#
# ##### Критерии оценки:
#
# - Функциональность (до 4 баллов)): Все методы работают корректно (запускаем код, и он работает)
# - Качество кода (до 3 баллов): Чистый, документированный код с обработкой ошибок (комментарии можно оставить из описания ДЗ + кратко описать, что вы дополнили самостоятельно, например, "добавлена токенизация `spacy`")
# - Структура проекта (до 2 баллов): Правильная организация файлов, как в условии ДЗ
# - Документация (до 1 балла): Наличие README и
